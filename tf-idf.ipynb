# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report, f1_score, hamming_loss

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("Data/Restaurant_ABSA_processed.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   review_en       800 non-null    object
#  1   review_cleaned  800 non-null    object
#  2   food            800 non-null    int64
#  3   price           800 non-null    int64
#  4   service         800 non-null    int64
#  5   ambiance        800 non-null    int64
#  6   miscellaneous   800 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 43.9+ KB

# %%
aspect_cols = ['food', 'service', 'price', 'ambiance', 'miscellaneous']

X_text_cleaned = df['review_cleaned']
X_text = df['review_en']
y = df[aspect_cols].values

# %%
X_train_text, X_test_text, y_train, y_test = train_test_split(
    X_text_cleaned, y, test_size=0.2, random_state=42
)
X_train_en, X_test_en, y_train, y_test = train_test_split(
    X_text, y, test_size=0.2, random_state=42
)

# %%
vectorizer = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1, 3)
)
X_train = vectorizer.fit_transform(X_train_text)
X_test = vectorizer.transform(X_test_text)

# %%
model_aspect = OneVsRestClassifier(
    LogisticRegression(
    max_iter=1000,
    C=2.0,
    class_weight='balanced'
)
)

model_aspect.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(C=2.0, class_weight='balanced',
#                                                  max_iter=1000))

# %%
y_pred_prob = model_aspect.predict_proba(X_test)

# %%
import numpy as np
from sklearn.metrics import f1_score

thresholds = {}

for i, aspect in enumerate(aspect_cols):
    best_t = 0.5
    best_f1 = 0

    for t in np.arange(0.2, 0.9, 0.02):
        y_pred_temp = (y_pred_prob[:, i] >= t).astype(int)
        f1 = f1_score(y_test[:, i], y_pred_temp)

        if f1 > best_f1:
            best_f1 = f1
            best_t = t

    thresholds[aspect] = round(best_t, 2)
    print(f"{aspect}: threshold={best_t:.2f}, F1={best_f1:.3f}")
# Out:
# food: threshold=0.56, F1=0.923
# service: threshold=0.56, F1=0.886
# price: threshold=0.44, F1=0.943
# ambiance: threshold=0.48, F1=0.892
# miscellaneous: threshold=0.28, F1=0.462

# %%
def apply_thresholds_advanced(y_prob, thresholds, top_k=2, remove_misc=True):
    """
    y_prob: (n_samples, n_aspects)
    thresholds: dict {aspect: threshold}
    top_k: giới hạn số aspect tối đa
    remove_misc: loại miscellaneous nếu có aspect khác
    """

    n_samples, n_aspects = y_prob.shape
    y_pred = np.zeros_like(y_prob)

    for i in range(n_samples):
        probs = y_prob[i]

        # ===== STEP 1: chọn theo threshold =====
        selected = [
            j for j in range(n_aspects)
            if probs[j] >= thresholds[aspect_cols[j]]
        ]

        # ===== STEP 2: fallback nếu không có =====
        if len(selected) == 0:
            selected = [np.argmax(probs)]

        # ===== STEP 3: loại miscellaneous nếu có class khác =====
        if remove_misc and len(selected) > 2:
            selected = [
                j for j in selected
                if aspect_cols[j] != "miscellaneous"
            ]
            if len(selected) == 0:
                selected = [np.argmax(probs)]

        # ===== STEP 4: giới hạn top-k =====
        if len(selected) > top_k:
            selected = sorted(selected, key=lambda j: probs[j], reverse=True)[:top_k]

        # ===== STEP 5: gán nhãn =====
        for j in selected:
            y_pred[i, j] = 1

    return y_pred

y_pred_opt = apply_thresholds_advanced(
    y_pred_prob,
    thresholds,
    top_k=2,
    remove_misc=True
)

# %%
from sklearn.metrics import classification_report, f1_score

print(classification_report(y_test, y_pred_opt, target_names=aspect_cols))

print("F1 Micro:", f1_score(y_test, y_pred_opt, average='micro'))
print("F1 Macro:", f1_score(y_test, y_pred_opt, average='macro'))
# Out:
#                precision    recall  f1-score   support
#
#          food       0.93      0.92      0.92       118
#       service       0.97      0.81      0.89        48
#         price       0.92      0.95      0.94        77
#      ambiance       0.88      0.90      0.89        41
# miscellaneous       0.58      0.60      0.59        30
#
#     micro avg       0.89      0.88      0.88       314
#     macro avg       0.86      0.84      0.85       314
#  weighted avg       0.90      0.88      0.88       314
#   samples avg       0.90      0.88      0.88       314
#
# F1 Micro: 0.8842443729903537
# F1 Macro: 0.8454136389648932

# %%
# Step 1: Prepare new review text
new_reviews = [
    "The food is cheap, but I don't think it's kept very fresh.",
    "Great ambiance and reasonable prices"
]

# Step 2: Encode reviews using the same SentenceTransformer
X_new = vectorizer.transform(new_reviews)

# Step 3: Get probability predictions
y_pred_prob_new = model_aspect.predict_proba(X_new)

# Step 4: Apply optimized thresholds
y_pred_new = apply_thresholds_advanced(
    y_pred_prob_new,
    thresholds,
    top_k=2,
    remove_misc=True
)

# Step 5: Display results
for i, review in enumerate(new_reviews):
    predicted_aspects = [aspect_cols[j] for j in range(len(aspect_cols)) if y_pred_new[i, j] == 1]
    print(f"Review: {review}")
    print(f"Predicted Aspects: {predicted_aspects}\n")
# Out:
# Review: The food is cheap, but I don't think it's kept very fresh.
# Predicted Aspects: ['food', 'price']
#
# Review: Great ambiance and reasonable prices
# Predicted Aspects: ['price', 'ambiance']

# %%
# Find samples where prediction differs from actual label
misclassified_indices = []

for i in range(len(y_test)):
    if not np.array_equal(y_pred_opt[i], y_test[i]):
        misclassified_indices.append(i)

print(f"Total misclassified samples: {len(misclassified_indices)} out of {len(y_test)}\n")

# Display details of wrong predictions
for idx in misclassified_indices[:10]:  # Show first 10 misclassified
    print(f"{'='*80}")
    print(f"Sample Index: {idx}")
    print(f"Review: {X_test_en.iloc[idx]}")
    print(f"Cleaned Review: {X_test_text.iloc[idx]}")
    print(f"\nTrue Labels: {[aspect_cols[j] for j in range(len(aspect_cols)) if y_test[idx, j] == 1]}")
    print(f"Predicted: {[aspect_cols[j] for j in range(len(aspect_cols)) if y_pred_opt[idx, j] == 1]}")
    print(f"Probabilities: {dict(zip(aspect_cols, y_pred_prob[idx].round(3)))}")
    print()
# Out:
# Total misclassified samples: 42 out of 160
#
# ================================================================================
# Sample Index: 5
# Review: If you want good coffee, you need a quiet environment.
# Cleaned Review: want good coffee need quiet environment
#
# True Labels: ['food', 'ambiance']
# Predicted: ['ambiance', 'miscellaneous']
# Probabilities: {'food': np.float64(0.426), 'service': np.float64(0.338), 'price': np.float64(0.194), 'ambiance': np.float64(0.851), 'miscellaneous': np.float64(0.383)}
#
# ================================================================================
# Sample Index: 10
# Review: The test was fair but their service was not good.
# Cleaned Review: test fair service good
#
# True Labels: ['food', 'service']
# Predicted: ['service', 'miscellaneous']
# Probabilities: {'food': np.float64(0.382), 'service': np.float64(0.919), 'price': np.float64(0.144), 'ambiance': np.float64(0.275), 'miscellaneous': np.float64(0.33)}
#
# ================================================================================
# Sample Index: 11
# Review: There is no extra decoration and the service is decent.
# Cleaned Review: extra decoration service decent
#
# True Labels: ['service', 'ambiance']
# Predicted: ['service', 'miscellaneous']
# Probabilities: {'food': np.float64(0.307), 'service': np.float64(0.798), 'price': np.float64(0.206), 'ambiance': np.float64(0.479), 'miscellaneous': np.float64(0.289)}
#
# ================================================================================
# Sample Index: 17
# Review: The broth of the chicken polao was absolutely delicious and the atmosphere was very calm in the restaurant.
# Cleaned Review: broth chicken polao absolutely delicious atmosphere calm restaurant
#
# True Labels: ['food', 'ambiance']
# Predicted: ['ambiance']
# Probabilities: {'food': np.float64(0.466), 'service': np.float64(0.196), 'price': np.float64(0.435), 'ambiance': np.float64(0.853), 'miscellaneous': np.float64(0.182)}
#
# ================================================================================
# Sample Index: 26
# Review: There is no Bengali food item in the menu but the price seems very low.
# Cleaned Review: bengali food item menu price seems low
#
# True Labels: ['price', 'miscellaneous']
# Predicted: ['food', 'price']
# Probabilities: {'food': np.float64(0.624), 'service': np.float64(0.189), 'price': np.float64(0.829), 'ambiance': np.float64(0.252), 'miscellaneous': np.float64(0.258)}
#
# ================================================================================
# Sample Index: 32
# Review: I would recommend this restaurant for quick delivery and not too expensive.
# Cleaned Review: would recommend restaurant quick delivery expensive
#
# True Labels: ['service', 'price']
# Predicted: ['price', 'ambiance']
# Probabilities: {'food': np.float64(0.463), 'service': np.float64(0.349), 'price': np.float64(0.568), 'ambiance': np.float64(0.509), 'miscellaneous': np.float64(0.309)}
#
# ================================================================================
# Sample Index: 37
# Review: I like everything very much but I will deduct a number because the seat is not very comfortable.
# Cleaned Review: like everything much deduct number seat comfortable
#
# True Labels: ['ambiance', 'miscellaneous']
# Predicted: ['miscellaneous']
# Probabilities: {'food': np.float64(0.544), 'service': np.float64(0.354), 'price': np.float64(0.396), 'ambiance': np.float64(0.361), 'miscellaneous': np.float64(0.541)}
#
# ================================================================================
# Sample Index: 38
# Review: The management of the restaurant knows how to run it well, the food comes as soon as the order is placed.
# Cleaned Review: management restaurant know run well food come soon order placed
#
# True Labels: ['service', 'miscellaneous']
# Predicted: ['food', 'ambiance']
# Probabilities: {'food': np.float64(0.589), 'service': np.float64(0.428), 'price': np.float64(0.272), 'ambiance': np.float64(0.564), 'miscellaneous': np.float64(0.449)}
#
# ================================================================================
# Sample Index: 40
# Review: The chaomin chicken sizes were good and tasted good too.
# Cleaned Review: chaomin chicken size good tasted good
#
# True Labels: ['food']
# Predicted: ['food', 'miscellaneous']
# Probabilities: {'food': np.float64(0.856), 'service': np.float64(0.311), 'price': np.float64(0.35), 'ambiance': np.float64(0.239), 'miscellaneous': np.float64(0.432)}
#
# ================================================================================
# Sample Index: 41
# Review: The shik kebabs are fun to eat but the environment in which they are being prepared is not very clean.
# Cleaned Review: shik kebab fun eat environment prepared clean
#
# True Labels: ['food', 'ambiance']
# Predicted: ['ambiance', 'miscellaneous']
# Probabilities: {'food': np.float64(0.556), 'service': np.float64(0.334), 'price': np.float64(0.357), 'ambiance': np.float64(0.648), 'miscellaneous': np.float64(0.33)}
