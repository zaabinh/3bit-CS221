# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("Data/Restaurant_ABSA_aspect_corrections.csv")
len(df)
# Out:
# 103

# %%
df.columns
# Out:
# Index(['source_row', 'review_en', 'review_cleaned', 'food', 'price', 'service',
#        'ambiance', 'miscellaneous', 'explain'],
#       dtype='object')
